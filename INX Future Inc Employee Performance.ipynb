# %% [markdown]
# # INX Future Inc Employee Performance Analysis
#
# ## Problem Statement
# INX Future Inc is facing a decline in employee performance and client satisfaction.
# The objective of this project is to analyze employee data and identify key factors
# affecting performance, and provide insights to improve overall productivity.
#
# ## Objective
# - Identify factors affecting employee performance
# - Analyze employee data using EDA techniques
# - Build a machine learning model to predict performance
# - Provide business insights and recommendations
#
# ## Dataset Description
# The dataset contains employee-related information such as age, department, experience,
# education, job role, and performance rating.
#
# ## Tools & Technologies Used
# - Python
# - Pandas
# - NumPy
# - Matplotlib & Seaborn
# - Machine Learning (Random Forest)
#
# ## Project Workflow
# 1. Data Loading
# 2. Data Cleaning
# 3. Exploratory Data Analysis (EDA)
# 4. Feature Engineering
# 5. Model Building
# 6. Evaluation
# 7. Conclusion

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("INX_Future_Inc_Employee_Performance.csv")
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df.dropna(inplace=True)

# %%
sns.countplot(x='PerformanceRating', data=df)
plt.title("Performance Rating Count")
plt.show()

# %%
sns.boxplot(x='PerformanceRating', y='Age', data=df)
plt.title("Age vs Performance")
plt.show()

# %%
for col in df.columns:
    print(col)
# Out:
# EmpNumber
# Age
# Gender
# EducationBackground
# MaritalStatus
# EmpDepartment
# EmpJobRole
# BusinessTravelFrequency
# DistanceFromHome
# EmpEducationLevel
# EmpEnvironmentSatisfaction
# EmpHourlyRate
# EmpJobInvolvement
# EmpJobLevel
# EmpJobSatisfaction
# NumCompaniesWorked
# OverTime
# EmpLastSalaryHikePercent
# EmpRelationshipSatisfaction
# TotalWorkExperienceInYears
# TrainingTimesLastYear
# EmpWorkLifeBalance
# ExperienceYearsAtThisCompany
# ExperienceYearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager
# Attrition
# PerformanceRating

# %%
df.columns = df.columns.str.strip().str.lower()
df.columns
# Out:
# Index(['empnumber', 'age', 'gender', 'educationbackground', 'maritalstatus',
#        'empdepartment', 'empjobrole', 'businesstravelfrequency',
#        'distancefromhome', 'empeducationlevel', 'empenvironmentsatisfaction',
#        'emphourlyrate', 'empjobinvolvement', 'empjoblevel',
#        'empjobsatisfaction', 'numcompaniesworked', 'overtime',
#        'emplastsalaryhikepercent', 'emprelationshipsatisfaction',
#        'totalworkexperienceinyears', 'trainingtimeslastyear',
#        'empworklifebalance', 'experienceyearsatthiscompany',
#        'experienceyearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'attrition', 'performancerating'],
#       dtype='object')

# %%
sns.countplot(x='empdepartment', hue='performancerating', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='performancerating', y='age', data=df)
plt.title("Age vs Performance")
plt.show()

# %%
sns.countplot(x='gender', hue='performancerating', data=df)
plt.title("Gender vs Performance")
plt.show()

# %%
sns.countplot(x='gender', hue='performancerating', data=df)
plt.title("Gender vs Performance")
plt.show()

# %%
sns.boxplot(x='performancerating', y='totalworkexperienceinyears', data=df)
plt.show()

# %% [markdown]
# - ## Insights
#
# - Employees from certain departments show higher performance.
# - Age and experience have an impact on performance.
# - Some departments need improvement in employee performance.

# %%
df = pd.get_dummies(df)

# %%
from sklearn.model_selection import train_test_split

X = df.drop('performancerating', axis=1)
y = df['performancerating']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8

# %%
import pandas as pd

feature_importance = pd.Series(model.feature_importances_, index=X.columns)
feature_importance.sort_values(ascending=False).head(10)
# Out:
# empenvironmentsatisfaction      0.107930
# emplastsalaryhikepercent        0.107337
# yearssincelastpromotion         0.046876
# emphourlyrate                   0.031617
# experienceyearsincurrentrole    0.031358
# experienceyearsatthiscompany    0.030234
# age                             0.028033
# yearswithcurrmanager            0.025672
# distancefromhome                0.025659
# totalworkexperienceinyears      0.025167
# dtype: float64

# %% [markdown]
# ## Conclusion
#
# - Employee performance depends on department, experience, and age.
# - The model successfully predicts performance with good accuracy.
# - Training and engagement programs can improve low-performing employees.

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8

# %%
feature_importance = pd.Series(model.feature_importances_, index=X.columns)
feature_importance.sort_values(ascending=False).head(10)
# Out:
# empenvironmentsatisfaction      0.107930
# emplastsalaryhikepercent        0.107337
# yearssincelastpromotion         0.046876
# emphourlyrate                   0.031617
# experienceyearsincurrentrole    0.031358
# experienceyearsatthiscompany    0.030234
# age                             0.028033
# yearswithcurrmanager            0.025672
# distancefromhome                0.025659
# totalworkexperienceinyears      0.025167
# dtype: float64

# %% [markdown]
# - Important features like experience, department, and age influence performance.

# %% [markdown]
# ## Final Conclusion
#
# - Employee performance is influenced by multiple factors such as department, age, and experience.
# - The machine learning model successfully predicted performance with good accuracy.
# - Identifying low-performing employees can help management take better decisions.
